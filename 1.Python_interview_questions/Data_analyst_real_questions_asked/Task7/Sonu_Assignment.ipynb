# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a Pandas DataFrame:

# %%
df = pd.read_csv("deal_data.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'SourceFundingID', 'Source', 'Domain', 'SourceCompanyID',
#        'PostMoneyValuation', 'Type', 'SourceType', 'Amount', 'Original_Date',
#        'Date', 'MonthUnknown', 'CreatedAt', 'UpdatedAt', 'VentureStage',
#        'Type_combined', 'CurrencyCode', 'ValuationCurrencyCode', 'ID', 'Tech',
#        'Agency Consultancy', 'Ecosystem', 'GoogleCountry', 'GoogleCity',
#        'Sectors', 'Region', 'FormationDate', 'Amount_ExchangeRate',
#        'Amount_USD', 'PostMoneyValuationUSD'],
#       dtype='object')

# %% [markdown]
# Define a function to clean and standardize the funding round types

# %%
def clean_funding_round(type_combined):
    type_combined = type_combined.lower()  # Convert to lowercase
    type_combined = type_combined.replace('venture', 'series')  # Replace 'venture' with 'series'
    return type_combined

# %% [markdown]
# Apply the clean_funding_round function to the 'Type_combined' column

# %%
df['Type_combined'] = df['Type_combined'].apply(clean_funding_round)

# %% [markdown]
# Define the priority order for sources

# %%
source_priority = {
    'Pitchbook': 1,
    'Crunchbase': 2,
    'Dealroom': 3
    
}

# %% [markdown]
# Sort the DataFrame by 'Original_Date' and source priority

# %%
df['SourcePriority'] = df['Source'].map(source_priority)
df.sort_values(by=['Original_Date', 'SourcePriority'], ascending=[True, True], inplace=True)

# %% [markdown]
# Deduplicate the funding rounds based on the deal span of 190 days

# %%
# Define a threshold for deal span (in days)
deal_span_threshold = 190

# Create a mask to identify duplicate funding rounds
mask = df.duplicated(subset=['Type_combined', 'Original_Date'], keep='first') & df['SourcePriority'].duplicated(keep='first')

# Filter out duplicate funding rounds
df = df[~mask]

# %% [markdown]
# Remove the 'SourcePriority' column

# %%
df = df.drop(columns=['SourcePriority'])

# %%
df.head(100)
# Out:
#       Unnamed: 0                       SourceFundingID      Source  \
# 7541        7541  e578d476-e42a-47a3-aa22-a905633fa840  Crunchbase
# 4629        4629  71698dfe-767e-4756-a1b1-01253d9f04c1  Crunchbase
# 5374        5374  8cfbfce9-a8d5-4f46-b068-e2d672797495  Crunchbase
# 4284        4284  63ebc69d-2559-4198-a73d-d672a9348acd  Crunchbase
# 5381        5381  8d537add-cd07-4b01-aa12-c9de8ca94e1c  Crunchbase
# ...          ...                                   ...         ...
# 8617        8617                                129693    Dealroom
# 8858        8858                                163508    Dealroom
# 7278        7278  dad4cee2-e436-772e-f678-c367b5cddb4d  Crunchbase
# 3788        3788  5181cc29-2d67-6e0d-b576-7ce418c1aade  Crunchbase
# 421          421  105d3dec-3e57-ff09-2f06-58119fa8881f  Crunchbase
#
#              Domain                       SourceCompanyID  PostMoneyValuation  \
# 7541            NaN  4f7b0e5f-4171-4ee7-ac11-e20730d4e370                 NaN
# 4629            NaN  14bf5c0a-b5d4-48e4-b600-cec9327d54ef                 NaN
# 5374            NaN  ec3fc2a9-50fd-4f75-b667-6b8df9540023                 NaN
# 4284            NaN  e2b72bc9-7bea-46ce-b220-6963e75bb9b6                 NaN
# 5381            NaN  3a40bd8c-8e23-4697-8815-02e7908162d1                 NaN
# ...             ...                                   ...                 ...
# 8617  lexiquest.com                               1422715                 NaN
# 8858   netformx.com                                 78667                 NaN
# 7278    altoweb.com  2eafb1fe-38a6-7778-bc1d-72c7ee43de12                 NaN
# 3788   ameranth.com  bd2f88e5-5b43-fa90-f32b-0419988b462e                 NaN
# 421   complient.com  4705470f-e30c-73b2-38b0-51423dd2e6cb                 NaN
#
#          Type SourceType      Amount              Original_Date  ...  \
# 7541     seed   pre seed    250000.0  1919-01-01 00:00:00+00:00  ...
# 4629     seed       seed         NaN  1982-01-01 00:00:00+00:00  ...
# 5374  venture    venture         NaN  1986-01-01 00:00:00+00:00  ...
# 4284  venture    venture    125000.0  1987-01-01 00:00:00+00:00  ...
# 5381     seed       seed         NaN  1987-01-01 00:00:00+00:00  ...
# ...       ...        ...         ...                        ...  ...
# 8617  venture   series c  25000000.0  2000-06-01 00:00:00+00:00  ...
# 8858  venture   series b  15000000.0  2000-06-01 00:00:00+00:00  ...
# 7278  venture  venture b         NaN  2000-06-09 00:00:00+00:00  ...
# 3788     seed       seed         NaN  2000-06-20 00:00:00+00:00  ...
# 421   venture    venture  44000000.0  2000-06-29 00:00:00+00:00  ...
#
#      Agency Consultancy       Ecosystem  GoogleCountry GoogleCity  \
# 7541                NaN             NaN            NaN        NaN
# 4629                NaN             NaN            NaN        NaN
# 5374                NaN             NaN            NaN        NaN
# 4284                NaN             NaN            NaN        NaN
# 5381                NaN             NaN            NaN        NaN
# ...                 ...             ...            ...        ...
# 8617              False   New York City  United States   New York
# 8858              False  Silicon Valley  United States   San Jose
# 7278              False  Silicon Valley  United States  Palo Alto
# 3788              False       San Diego  United States  San Diego
# 421               False       Cleveland  United States      Solon
#
#                    Sectors            Region              FormationDate  \
# 7541                   NaN               NaN                        NaN
# 4629                   NaN               NaN                        NaN
# 5374                   NaN               NaN                        NaN
# 4284                   NaN               NaN                        NaN
# 5381                   NaN               NaN                        NaN
# ...                    ...               ...                        ...
# 8617                EdTech  Northern America  1997-01-01 00:00:00+00:00
# 8858               FinTech  Northern America  1994-01-01 00:00:00+00:00
# 7278                EdTech  Northern America  1999-01-01 00:00:00+00:00
# 3788  EdTech;Digital Media  Northern America  1996-01-01 00:00:00+00:00
# 421                    NaN  Northern America  1997-01-01 00:00:00+00:00
#
#      Amount_ExchangeRate  Amount_USD PostMoneyValuationUSD
# 7541                 1.0    250000.0                   NaN
# 4629                 NaN         NaN                   NaN
# 5374                 NaN         NaN                   NaN
# 4284                 1.0    125000.0                   NaN
# 5381                 NaN         NaN                   NaN
# ...                  ...         ...                   ...
# 8617                 1.0  25000000.0                   NaN
# 8858                 1.0  15000000.0                   NaN
# 7278                 NaN         NaN                   NaN
# 3788                 NaN         NaN                   NaN
# 421                  1.0  44000000.0                   NaN
#
# [100 rows x 30 columns]

# %% [markdown]
# Save the deduplicated DataFrame to a new CSV file

# %%
df.to_csv('deduplicated_funding_data.csv', index=False)
