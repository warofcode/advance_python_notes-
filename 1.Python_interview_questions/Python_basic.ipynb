# %% [markdown]
#                                                        # Python Interview Questions

# %% [markdown]
# # Question 1. What is python Please explain ?

# %% [markdown]
# Python is a high-level programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991. Python emphasizes code readability with its clear and concise syntax, making it an excellent language for beginners and experienced programmers.

# %% [markdown]
# Python is versatile and supports multiple programming paradigms, including procedural, object-oriented, and functional programming styles. It has a vast standard library and a thriving ecosystem of third-party packages and frameworks that extend its capabilities for various applications, such as web development, data science, artificial intelligence, machine learning, automation, and more.

# %% [markdown]
# Python is gaining huge popularity because it's easy to use and can handle many tasks with just a little bit of code. It's used in exciting fields like machine learning, AI, web development, and scraping data from websites. Because of this, there's a big demand for people who know how to work with Python, both in India and globally.

# %% [markdown]
# One of Python's key features is its dynamic typing and automatic memory management, which simplifies development and enhances productivity. It's widely used by developers, scientists, researchers, and educators due to its flexibility, ease of learning, and strong community support.

# %% [markdown]
# # Question2: What do you mean by dynamically typed language ?

# %% [markdown]
# In programming, "typing" means checking the data types of variables.

# %% [markdown]
# Type checking is done in two Stages:

# %% [markdown]
# Static - Checking Data types before running the code.

# %% [markdown]
# Dynamic: Checking types while the code is running.

# %% [raw]
# Statically typed:

# %% [markdown]
# A statically typed language is one where the data types of variables are checked before the program is executed, typically during the compilation phase. In such languages, you need to explicitly declare the data type of each variable, and the compiler ensures that the operations performed on these variables are type-safe. If there is a mismatch between the declared data type and the operation being performed, the compiler will raise an error, preventing the program from running.

# %% [markdown]
# In simple terms, in statically typed languages like C or Java, you have to tell the compiler what type each variable is, and it makes sure you use them correctly throughout your code.

# %% [markdown]
# Example of Statically typed: Java , C++ ,C , Swift(iOS, macOS)

# %% [raw]
# Dynamically typed:

# %% [markdown]
# In a dynamically typed language, you don't need to declare the data type of a variable explicitly. Instead, the data type of a variable is determined automatically at runtime based on the value assigned to it. This means you can assign different types of values to the same variable without having to change its type declaration.

# %% [markdown]
# Example: Python ,Ruby , PHP ,Perl

# %% [raw]
# Lets understand the difference by example:

# %% [raw]
# Statically typed language code:

# %% [markdown]
# Lets write a simple c language code

# %% [raw]
# #include <stdio.h>
#
# int main() {
#
#     int x = 5; // Declare and initialize an integer variable
#
#     printf("The value of x is: %d\n", x);
#
#     return 0;
# }

# %% [raw]
# Dynamically typed language code:

# %% [raw]
# x = 5  # Assigning value 5 to variable x with out telling what kind of value x will hold
#
# print("The value of x is:", x)

# %% [markdown]
# # Question 3: Please explain PEP 8 ?

# %% [markdown]
# PEP 8 is a style guideline for Python code. "PEP" stands for Python Enhancement Proposal, and PEP 8 specifically focuses on how to format Python code to improve its readability and maintainability. It was authored by Guido van Rossum, Barry Warsaw, and Nick Coghlan, and it's considered  standard for Python code style.
#
# PEP 8 is a coding style guide for the Python programming language. PEP stands for Python Enhancement Proposal, and PEP 8 provides guidelines for how to write Python code that is easy to read and maintain. The primary goal of PEP 8 is to make Python code consistent across different projects, so that it is easier for developers to read and understand code written by others.
#
# PEP 8 covers topics such as code layout, indentation, naming conventions, function and class design, and comments. The guide recommends using four spaces for indentation, limiting line length to 79 characters, using clear and descriptive variable names, and following a consistent naming convention for classes, functions, and variables.
#
# Following PEP 8 guidelines is not required, but it is highly recommended for Python programmers. Adhering to PEP 8 can make your code more readable and maintainable, and can make it easier for others to understand and work with your code.

# %% [markdown]
# PEP 8 covers various aspects of Python code formatting, including:

# %% [raw]
# 1. Indentation: Recommends using 4 spaces per indentation level.

# %% [raw]
# 2. Whitespace: Defines conventions for using whitespace around operators, commas, colons, and parentheses.

# %% [raw]
# 3.Line Length: Suggests limiting lines to 79 characters in length to improve readability.

# %% [raw]
# Imports: Specifies guidelines for organizing and formatting import statements.

# %% [markdown]
# PEP 8 suggests lines should be limited to 79 characters. This allows you to have multiple files open next to one another, while also avoiding line wrapping.
#
# Of course, keeping statements to 79 characters or fewer isn’t always possible. Therefore, PEP 8 also outlines ways to allow statements to run over several lines.
#
# Python will assume line continuation if code is contained within parentheses, brackets, or braces:

# %% [raw]
# Example 1:

# %%
def my_function(arg1,arg2,arg3,arg4,arg5,arg6,
               arg7):
    return None
print(my_function(1,2,3,4,5,6,7))
# Out:
# None

# %% [markdown]
# Example 2:

# %%
print("hi i m learning \
python")
# Out:
# hi i m learning python

# %% [markdown]
# # Question 4: What is pip ?

# %% [markdown]
# Pip is a package manager for Python, which means it's a tool used to install and manage software packages written in Python.The abbreviation "PIP" stands for "Pip Installs Packages". Here's a step-by-step explanation of how to use pip:

# %% [markdown]
# 1.Install Python:
#
# First, make sure you have Python installed on your system. Pip usually comes pre-installed with Python versions 3.4 and above, so if you have a recent version of Python, you should already have pip installed. You can check if pip is installed by opening a terminal or command prompt and typing pip --version.

# %%
pip --version
# Out:
# pip 24.0 from C:\Users\rkt65\anaconda3\Lib\site-packages\pip (python 3.11)
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 2. Update pip (optional):

# %% [markdown]
# It's a good practice to update pip to the latest version before using it. You can do this by running the following command:

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 3. Install a package:
#
# To install a Python package using pip, you can use the following command:

# %% [raw]
# pip install package_name

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 4. Install a specific version of a package (optional):

# %% [markdown]
#  If you need a specific version of a package, you can specify it during installation. For example:

# %% [raw]
# pip install package_name==version_number

# %%
pip install requests==2.25.1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 5. Install packages from a requirements file (optional)

# %% [markdown]
# You can also install multiple packages at once from a requirements file. A requirements file is a simple text file listing all the packages you want to install, with each package on a separate line. To install packages from a requirements file, use the following command:

# %% [raw]
# pip install -r requirements.txt

# %% [markdown]
# 6. Upgrade a package

# %% [raw]
# pip install --upgrade package_name

# %% [markdown]
# Replace package_name with the name of the package you want to upgrade.

# %% [markdown]
# 7. Remove a package

# %% [raw]
# pip uninstall package_name

# %% [markdown]
# 8. list all installed packages

# %% [markdown]
# This command lists all installed packages along with their versions. It's handy when you want to see what packages are installed in your Python environment. You can run it simply by typing:

# %%
pip list
# Out:
# Package                           Version
# --------------------------------- ------------
# aiobotocore                       2.7.0
# aiohttp                           3.9.3
# aioitertools                      0.7.1
# aiosignal                         1.2.0
# alabaster                         0.7.12
# altair                            5.0.1
# anaconda-anon-usage               0.4.3
# anaconda-catalogs                 0.2.0
# anaconda-client                   1.12.3
# anaconda-cloud-auth               0.1.4
# anaconda-navigator                2.5.2
# anaconda-project                  0.11.1
# anyio                             4.2.0
# appdirs                           1.4.4
# archspec                          0.2.1
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.2.3
# astroid                           2.14.2
# astropy                           5.3.4
# asttokens                         2.0.5
# ...

# %% [markdown]
# 9. pip freeze:

# %% [markdown]
# This command outputs the names and versions of installed packages in a format that can be used to recreate the environment. It's often used to generate a requirements file. You can run it like this:

# %% [raw]
# pip freeze

# %% [markdown]
# 10. Generate Requirements.txt File

# %% [markdown]
# To merge all your packages in a single file, we generate a requirements.txt file. It helps all the developers to use the package at a time. Using the command, pip freeze > requirements.txt, a requirements.txt file is generated which stores all the required packages.

# %% [raw]
# pip freeze > requirements.txt

# %% [markdown]
# 10. Remove All Packages Installed By Pip

# %% [markdown]
# First, you need to generate a list of all installed packages. You can do this by using the pip freeze command and redirecting its output to a text file. Run the following command in your terminal or command prompt:

# %% [markdown]
# Below command will generate a txt file

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Instead of removing packages one by one, you can directly remove all packages installed by pip to save time. to remove all packages you
# can run below command.

# %% [raw]
# pip freeze > requirements.txt && pip uninstall -e requirements.txt -y

# %% [markdown]
# # 5. How Python Internally works Please explain ?

# %% [markdown]
# Python is Both Compiled as well as Interpreted

# %% [markdown]
# .

# %% [markdown]
# "Python is an interpreted language", is the most common saying, which is also written in various books, but the hidden fact is Python is both compiled as well as an interpreted language. This means when we run a python code, it is first compiled and then interpreted line by line. The compilation part is mostly hidden from the user. While running the code, Python generates a byte code internally, this byte code is then converted using a python virtual machine (p.v.m) to generate the output.

# %% [markdown]
# ![Internal-working-of-Python-(1).gif](attachment:bf7ef5e7-5368-4c6b-a433-2f8235d56af0.gif)

# %% [markdown]
# Now, let us try to prove the fact python is both compiled as well interpreted.

# %% [markdown]
# How is Python Source Code Converted into Executable Code lets understand it step by step

# %% [markdown]
# For example you have a .py file with the name (my_code.py)

# %% [markdown]
# step 1.  When you have a Python source file (a file ending with .py), it's converted into bytecode (.pyc file ) by python compiler. Bytecode is a set of instructions that the Python interpreter can understand. This conversion process is done by the Python compiler.

# %% [raw]
# Note-> this bytecode is created in same directory with the new directory name  __pycache__. Inside __pycache__ you will find the bytecode.
# name of this will be like (my_code.cpython-312). (before first .(dot) it will be same as your file name)
#
# Note-> you will not find this folder for every .py file you run. you will only find this when you import a module inside your source file.
#
# Note-> if you want to generate the bytecode for  your . py file you can forcfully do that with below command.
#
# below command will create the __pycache__ directory and will create a .pyc file named (rohit.cpython-312)

# %%
# below command will create a .pyc file (bytecode)
import py_compile
py_compile.complie('rohit.py')    # rohit.py is your file name

# %% [markdown]
# ![image.png](attachment:12b0e19a-05a5-4b21-87ba-945783aea41f.png)

# %% [markdown]
# If you want to run this bytecode than you can do it with the help of cmd. just open cmd in your __pycache__. and run this as below.

# %% [markdown]
# ![image.png](attachment:78050ed5-79fa-4976-8bd6-80fd209b6a33.png)

# %% [markdown]
# you will still get the same output.

# %% [markdown]
# Step 2:   Byte code that is .pyc file is then sent to the Python Virtual Machine(PVM) which is the Python interpreter. PVM converts the Python byte code into machine-executable code and in this interpreter reads and executes the given file line by line. If an error occurs during this interpretation then the conversion is halted with an error message.
#
# Step 3:   Within the PVM the bytecode is converted into machine code that is the binary language consisting of 0’s and 1’s. This binary language is only understandable by the CPU of the system as it is highly optimized for the machine code.
#
# Step 4:   In the last step, the final execution occurs where the CPU executes the machine code and the final desired output will come as according to your program.

# %% [markdown]
# # Questin 6:Please explain below statements ?

# %% [markdown]
#     1. pass
#
#     b. continue
#
#     c. break

# %% [markdown]
# 1. Pass statement

# %% [markdown]
# In genral pass keyword is used to fill up the empty blocks
#
# The pass statement in Python is a null operation. It doesn't do anything when executed. It's used as a placeholder where syntactically required but no action is needed. It is often employed as a temporary placeholder when a statement is syntactically necessary but the program logic is not yet defined.

# %%
#Example
for i in range(5):
    
        pass  # Placeholder, no action needed

# %% [markdown]
# 2. Continue Statement

# %% [markdown]
# The continue statement is used to skip the rest of the code inside a loop for the current iteration, without terminating the loop entirely. It moves the control to the next iteration of the loop.
#
# Syntax:

# %%
for i in range(5):
    if i == 2:
        continue # skipping 2 (# if condition is true stop the current iteration)
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %% [markdown]
# 3. Break Statement

# %% [markdown]
# The break statement is used to exit a loop prematurely. When a break statement is encountered inside a loop, the loop is terminated immediately, and the program continues executing the code that follows the loop.
#
# Syntax:

# %%
for i in range(5):
    if i == 2:
        break # if condition is true terminate the entire loop
    print(i)
# Out:
# 0
# 1

# %%
# Question 7 : What is the difference between List and a Tuple ?
