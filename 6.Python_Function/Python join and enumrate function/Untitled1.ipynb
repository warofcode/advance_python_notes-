# %%
which python
# Out:
#   Cell In[1], line 1
#     which python
#           ^
# SyntaxError: invalid syntax

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\rkt65\anaconda3\python.exe

# %%
import sys
sys.version
# Out:
# '3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]'

# %%
import sys
sys.path
# Out:
# ['C:\\Users\\rkt65\\OneDrive\\Desktop\\1Python_RexGalaxy_Clasess\\Python map filter reduce',
#  'C:\\Users\\rkt65\\anaconda3\\python311.zip',
#  'C:\\Users\\rkt65\\anaconda3\\DLLs',
#  'C:\\Users\\rkt65\\anaconda3\\Lib',
#  'C:\\Users\\rkt65\\anaconda3',
#  '',
#  'C:\\Users\\rkt65\\anaconda3\\Lib\\site-packages',
#  'C:\\Users\\rkt65\\anaconda3\\Lib\\site-packages\\win32',
#  'C:\\Users\\rkt65\\anaconda3\\Lib\\site-packages\\win32\\lib',
#  'C:\\Users\\rkt65\\anaconda3\\Lib\\site-packages\\Pythonwin']

# %%
import sys
sys.path_hooks
# Out:
# [zipimport.zipimporter,
#  <function _frozen_importlib_external.FileFinder.path_hook.<locals>.path_hook_for_FileFinder(path)>]

# %%
import pkg_resources

# Get a list of all installed packages
installed_packages = pkg_resources.working_set

# Count the number of installed packages
num_installed_packages = len(installed_packages)

# Print the list of installed packages
print("List of installed packages:")
for package in installed_packages:
    print(package)

# Print the total number of installed packages
print("Total number of installed packages:", num_installed_packages)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       4 installed_packages = pkg_resources.working_set
#       6 # Count the number of installed packages
# ----> 7 num_installed_packages = len(installed_packages)
#       9 # Print the list of installed packages
#      10 print("List of installed packages:")
#
# TypeError: object of type 'WorkingSet' has no len()

# %%
import sys
sys.version
# Out:
# '3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]'

# %%
pip install numpy == 1.2.1

# %%
import os
try:
    user_paths = os.environ['PYTHONPATH'].split(os.pathsep)
except KeyError:
    user_paths = []
    
print(user_paths)
# Out:
# []

# %%
pip freeze
# Out:
# aiobotocore @ file:///C:/b/abs_1c1a_vjay2/croot/aiobotocore_1682537737724/work
# aiofiles @ file:///C:/b/abs_9ex6mi6b56/croot/aiofiles_1683773603390/work
# aiohttp @ file:///C:/b/abs_b78zt6vo64/croot/aiohttp_1694181126607/work
# aioitertools @ file:///tmp/build/80754af9/aioitertools_1607109665762/work
# aiosignal @ file:///tmp/build/80754af9/aiosignal_1637843061372/work
# aiosqlite @ file:///C:/b/abs_9djc_0pyi3/croot/aiosqlite_1683773915844/work
# alabaster @ file:///home/ktietz/src/ci/alabaster_1611921544520/work
# anaconda-anon-usage @ file:///C:/b/abs_f4tsjyl9va/croot/anaconda-anon-usage_1695310457827/work
# anaconda-catalogs @ file:///C:/b/abs_8btyy0o8s8/croot/anaconda-catalogs_1685727315626/work
# anaconda-client @ file:///C:/b/abs_80wttmgui4/croot/anaconda-client_1694625288614/work
# anaconda-cloud-auth @ file:///C:/b/abs_5cjpnu6wjb/croot/anaconda-cloud-auth_1694462130037/work
# anaconda-navigator @ file:///C:/b/abs_cfvv8k_j21/croot/anaconda-navigator_1704813334508/work
# ...

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.5
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anaconda-anon-usage           0.4.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.1
# anaconda-cloud-auth           0.1.3
# anaconda-navigator            2.5.2
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# ...

# %%
new_list = [1,2,"rohit","python","mysql",9.5,76,[1,2,3,4]]

def my_filter(item):
    
    return [item for item in new_list if is instance(item,str)]

new_list_with_filterfunc = list(filter(my_filter,new_list))
    
new_list_with_filterfunc
# Out:
#   Cell In[23], line 5
#     return [item for item in new_list if is instance(item,str)]
#                                          ^
# SyntaxError: invalid syntax

# %%
my_list = [1,2,"rohit","python","mysql",9.5,76,[1,2,3,4]]
