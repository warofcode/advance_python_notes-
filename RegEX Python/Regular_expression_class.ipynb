# %% [markdown]
# # Python RegEx

# %%
# A RegEx, or Regular Expression, is a sequence of characters that forms a search pattern.

# RegEx can be used to check if a string contains the specified search pattern.

# %%
# Python has a built-in package called re, which can be used to work with Regular Expressions.

# Import the re module:

# %% [markdown]
# # Example

# %%
# Search the string to see if it starts with "The" and ends with "Spain":
# * Means starts with 
# $ means ends with
import re

txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)

if (x):
  print("YES! We have a match!")
else:
  print("No match")
# Out:
# YES! We have a match!

# %% [markdown]
# # RegEx Functions

# %%
# Function                                                Description

# findall	                                    Returns a list containing all matches
# search	                                    Returns a Match object if there is a match anywhere in the string
# split	                                        Returns a list where the string has been split at each match
# sub	                                        Replaces one or many matches with a string

# %% [markdown]
# # Special Sequences

# %% [markdown]
# ![image.png](attachment:571ca931-2901-405a-9702-d772231c2374.png)

# %% [markdown]
# # Lets learn about Special Sequences one by one

# %% [raw]
# \A	     Returns a match if the specified characters are at the beginning of the string	    "\AThe"
#
# # this is opposite to \Z which look for string at the end of the string

# %% [markdown]
# # Example

# %%
import re
txt = "The python The the The"

#Check if the string starts with "The":
match = re.findall("\AThe", txt) # returns a list

print(match)
print("Type of your match is : ",type(match))

if match:
  print("Yes, there is a match!")
else:
  print("No match")
# Out:
# ['The']
# Type of your match is :  <class 'list'>
# Yes, there is a match!

# %% [raw]
# \b	Returns a match where the specified characters are at the beginning or at the end of a word     r"\bain"
#
# (the "r" in the beginning is making sure that the string is being treated as a "raw string")	    r"ain\b"

# %% [markdown]
# # Example

# %%
import re

txt = "aina The rain in Spain aina"

#Check if "ain" is present at the beginning of a WORD: it will not check for if ain at the end of the word

match = re.findall(r"\bain", txt) 

print(match)
S
if match:
  print("Yes, there is a match)
else:
  print("No match")
# Out:
# ['ain', 'ain']
# Yes, there is at least one match!

# %%
import re

txt = "The rain in spain"
match = re.findall(r"ain\b",txt) # it will return a list and in below line list will be checked whether its a true or false
if match:
    print("Match found")
    print("Your list of words is : ", match)
else:
    print("No match")
# Out:
# Match found
# Your list of words is :  ['ain', 'ain']

# %% [raw]
# \B	Returns a match where the specified characters are present, but NOT at the beginning (or at the end) of a word       r"\Bain"
#
# (the "r" in the beginning is making sure that the string is being treated as a "raw string")                             r"ain\B"

# %% [markdown]
# # Example

# %%
# \B is like opposite for \b
import re

txt = "aina The rain in Spain"

#Check if "ain" is present, but NOT at the beginning of a word: # it will not look for  anyword which has ain in the begining

match = re.findall(r"\Bain", txt)

print(match)

if match:                # if match == True dont get confuse
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['ain', 'ain']
# Yes, there is at least one match!

# %%
import re

txt = "The rain in Spain"

#Check if "ain" is present, but NOT at the end of a word:

match = re.findall(r"ain\B", txt)

print(match)

if match:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# []
# No match

# %% [raw]
# \d	Returns a match where the string contains digits (numbers from 0-9)	"\d"

# %%
import re

# txt2 = "The rain in Spain"
txt1 = "The rain in Spain1 ,2 ,9718292990"

#Check if the string contains any digits (numbers from 0-9): # 

x = re.findall("\d", txt1) # willl find only digits

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['1', '2', '9', '7', '1', '8', '2', '9', '2', '9', '9', '0']
# Yes, there is at least one match!

# %% [raw]
# \D	Returns a match where the string DOES NOT contain digits	"\D"

# %%
# \D is oppsite to \d
import re

txt = "The rain in Spain"

#Return a match at every no-digit character:

x = re.findall("\D", txt) # will levave only digits

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['T', 'h', 'e', ' ', 'r', 'a', 'i', 'n', ' ', 'i', 'n', ' ', 'S', 'p', 'a', 'i', 'n']
# Yes, there is at least one match!

# %% [raw]
# \s	Returns a match where the string contains a white space character	"\s"

# %%
import re

txt = "The rain in Spain"

#Return a match at every white-space character:

x = re.findall("\s", txt)

print(x)
print("total white space character : ",len(x))

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# [' ', ' ', ' ']
# total white space character :  3
# Yes, there is at least one match!

# %% [raw]
# \S	Returns a match where the string DOES NOT contain a white space character

# %%
import re

txt = "The rain in Spain"

#Return a match at every NON white-space character:

x = re.findall("\S", txt) # will return evrything except white space character

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")

# %% [markdown]
# \w	Returns a match where the string contains any word characters (characters from a to Z, digits from 0-9, and the underscore _ character)
#
# "\w"

# %%
import re

txt = "The rain in Spain 9_9 #"

#Return a match at every word character (characters from a to Z, digits from 0-9, and the underscore _ character):

x = re.findall("\w", txt)  # will return (a-z,0-9,_)  else will ignore

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# ['T', 'h', 'e', 'r', 'a', 'i', 'n', 'i', 'n', 'S', 'p', 'a', 'i', 'n', '9', '_', '9']
# Yes, there is at least one match!

# %% [raw]
# \W	Returns a match where the string DOES NOT contain any word characters	"\W"

# %%
import re

txt = "The rain in Spain"

#Return a match at every NON word character (characters NOT between a and Z. Like "!", "?" white-space etc.):

x = re.findall("\W", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# [' ', ' ', ' ']
# Yes, there is at least one match!

# %% [markdown]
# \Z	Returns a match if the specified characters are at the end of the string	"Spain\Z"

# %%
import re

txt = "We need to learn python" # remember these should not be space after string
# txt = "Hi this is new pyhton and all "
#Check if the string ends with "Spain":

match = re.findall("python\Z", txt)

print(match)

if match:
  print("Yes, there is a match!")
else:
  print("No match")
# Out:
# ['python']
# Yes, there is a match!

# %% [markdown]
# # Metacharacters

# %%
# Metacharacters are characters with a special meaning:

# Character	       Description	             Example	                                                 Try it

# []	           A set of characters	                                                                "[a-m]"	
# \	               Signals a special sequence (can also be used to escape special characters)	         "\d"	
# .                Any character (except newline character)	                                            "he..o"	
# ^                Starts with	                                                                        "^hello"	
# $                Ends with	                                                                        "world$"	
# *                Zero or more occurrences	                                                             "aix*"	
# +                One or more occurrences	                                                             "aix+"	
# {}               Exactly the specified number of occurrences	                                         "al{2}"	
# |                Either or	                                                                      "falls|stays"

# %% [markdown]
# ![image.png](attachment:0f537b6d-9d5a-4c5b-b6bc-05bef1fdd1d5.png)

# %% [markdown]
# # Sets

# %% [markdown]
# ![image.png](attachment:395b1b4a-2b55-442b-b407-abd8a4bab2ff.png)

# %%
# A set is a set of characters inside a pair of square brackets [] with a special meaning:

# Set	Description
# [arn]	Returns a match where one of the specified characters (a, r, or n) are present	
# [a-n]	Returns a match for any lower case character, alphabetically between a and n	
# [^arn]	Returns a match for any character EXCEPT a, r, and n	
# [0123]	Returns a match where any of the specified digits (0, 1, 2, or 3) are present	
# [0-9]	Returns a match for any digit between 0 and 9	
# [0-5][0-9]	Returns a match for any two-digit numbers from 00 and 59	
# [a-zA-Z]	Returns a match for any character alphabetically between a and z, lower case OR upper case	
# [+]	In sets, +, *, ., |, (), $,{} has no special meaning, so [+] means: return a match for any + character in the string

# %% [markdown]
# # The findall() Function

# %%
# The findall() function returns a list containing all matches.
import re

#Return a list containing every occurrence of "ai":     # it will return all occurences, however search will return only firt

txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
# Out:
# ['ai', 'ai']

# %%
# The list contains the matches in the order they are found.

# If no matches are found, an empty list is returned:

import re

string = "The rain in Spain"

#Check if "Portugal" is in the string:

x = re.findall("Portugal", string)
print(x)

if (x):           #meaning if x is not empty # in our case x is empty so else part is running 
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# []
# No match

# %% [markdown]
# # The search() Function

# %%
# The search() function searches the string for a match, and returns a Match object if there is a match.

# If there is more than one match, only the first occurrence of the match will be returned:

# If no matches are found, the value None is returned:

# %%
import re

txt = "The rain in Spain"
x = re.search("\s", txt)

print("The first white-space character is located in position:", x.start())
# Out:
# The first white-space character is located in position: 3

# %%
# If no matches are found, the value None is returned:

# %%
import re

txt = "The rain in Spain in rain agian"
x = re.search("rain", txt)
y=re.findall("rain",txt)
print(x)
print(y)
# it means from index 4 to 8 rain exists
# as we diccussed it will return only firt occurence however we have two rain in this string
# as you can see find all has returned all rain as we have only two
# Out:
# <re.Match object; span=(4, 8), match='rain'>
# ['rain', 'rain']

# %% [markdown]
# # The split() Function

# %%
# he split() function returns a list where the string has been split at each match:

# %%
import re

#Split the string at every white-space character:

txt = "The rain in Spain"
x = re.split("\s", txt)
print(x)

# it will return a list by splitting a whole string with white space character
# Out:
# ['The', 'rain', 'in', 'Spain']

# %%
# You can control the number of occurrences by specifying the maxsplit parameter:
import re

#Split the string at the first white-space character:

txt = "The rain in Spain"
x = re.split("\s", txt, 1)
y=re.split("ain",txt )  # we have two ain so it will make two splits as below
print(x)
print(y)
# it will split by 1 white space only
# Out:
# ['The', 'rain in Spain']
# ['The r', ' in Sp', '']

# %% [markdown]
# # The sub() Function

# %%
# The sub() function replaces the matches with the text of your choice:
import re

#Replace all white-space characters with the digit "_":

txt = "The rain in Spain"
x = re.sub("\s", "_", txt) # \s means white space  "_" underscore that is value to 
print(x)

# as you can see we have replaced all white spaces with underscore
# Out:
# The_rain_in_Spain

# %%
# You can control the number of replacements by specifying the count parameter:
import re

#Replace the first two occurrences of a white-space character with the digit _:

txt = "The rain in Spain"
x = re.sub("\s", "_", txt, 2)


print(x)

# as you can see we only have two underscore only becuase we limited it by 2
# Out:
# The_rain_in Spain

# %%
# replacing a word with pyhthon

text="My name is Rohit. I teach python"

import re

x=re.sub("Rohit","Rahul",text)
print(x)

# as you can see it replace "Rohit" with 'Rahul'
# Out:
# My name is Rahul. I teach python

# %% [markdown]
# # Match Object

# %%
# A Match Object is an object containing information about the search and the result.

# Note: If there is no match, the value None will be returned, instead of the Match Object.

# %%
import re

#The search() function returns a Match object:

txt = "The rain in Spain"
x = re.search("ai", txt)
print(x)
# Out:
# <re.Match object; span=(5, 7), match='ai'>

# %% [markdown]
# The Match object has properties and methods used to retrieve information about the search, and the result:

# %%
# .span() returns a tuple containing the start-, and end positions of the match.
# .string returns the string passed into the function
# .group() returns the part of the string where there was a match

# %%
.spain()
# Example
# Print the position (start- and end-position) of the first match occurrence.

# The regular expression looks for any words that starts with an upper case "S":

import re

#Search for an upper case "S" character in the beginning of a word, and print its position:

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.span())
# Out:
#   Cell In[22], line 1
#     .spain()
#     ^
# SyntaxError: invalid syntax

# %%
.string
# Print the string passed into the function:
import re

#The string property returns the search string:

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.string)

# %%
.group()
# Print the part of the string where there was a match.

# The regular expression looks for any words that starts with an upper case "S":
import re

txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.group())

# %% [markdown]
# # .compile()

# %%
txt = "The rain in Spain"
pattern=re.compile(r"\bS")        # pattern you want to find in the string 
matches=pattern.finditer(txt)     # this is iterator
for i in matches:
    print(i)

# %%
type(pattern)

# %%
type(matches)

# %%
txt="The rain in spain"              # This is our string in which we have to find pattern

pattern=re.compile(r"ain\b")         # find the pattern in whihch words end with ain
matches=pattern.finditer(txt)        # this is itrator which will return words 

for i in matches:                    # we have used for loop to print matches
    print(i)

# %%
# another example

txt="+0120-265364 +910120-265899 0120-265380"
pattern=re.compile(r"\d{3}-\d{6}")    # starting with 4 digist- 6 digits
matches=pattern.finditer(txt)
for i in matches:
    print(i)
